# %%
# place here all packages used

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import io
from google.colab import files

# saving images to your mydrive
from google.colab import drive
drive.mount('/content/gdrive')
images_dir = '/content/gdrive/My Drive'
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# ##**2018**

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-84cb50bf-94b1-4a0f-b1d4-dda42e335f08" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-84cb50bf-94b1-4a0f-b1d4-dda42e335f08">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving finc01_2018.csv to finc01_2018.csv

# %%
FIN2018 = open("finc01_2018.csv","r")

df_FIN2018 = pd.read_csv(FIN2018)
df_FIN2018 = df_FIN2018.drop(columns = ['Unnamed: 50','Unnamed: 49','Unnamed: 48','Unnamed: 47','Unnamed: 46','Unnamed: 45','Unnamed: 44','Unnamed: 43','Unnamed: 1'])
df_FIN2018.head()
# Out:
#   Table with row headers in column A and column headers in rows 8 through 9, 12 through 13, 19 through 20, 26 through 27, 36 through 37, 49 through 50, 65 through 66, 75 through 76, 85 through 86, and 99 through 100  \
# 0  FINC-01. Selected Characteristics of Families ...
# 1  Data reflect the implementation of an updated ...
# 2  For information on confidentiality protection,...
# 3  Source: U.S. Census Bureau, Current Population...
# 4  (Numbers in thousands. Families as of March of...
#
#   Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN        NaN        NaN
# 3        NaN        NaN        NaN        NaN        NaN        NaN
# 4        NaN        NaN        NaN        NaN        NaN        NaN
#
# ...

# %%
df_FIN2018.columns = [df_FIN2018.iloc[18]]

df_FIN2018 = df_FIN2018.drop(labels=18,axis=0)
df_FIN2018 = df_FIN2018.iloc[19:23]
df_FIN2018.head()
# Out:
# 18 Characteristic Under $5,000 $5,000 to  $9,999 $10,000 to $14,999  \
# 20      Northeast          291               201                255
# 21        Midwest          233               205                392
# 22          South        1,017               531                809
# 23           West          399               276                360
#
# 18 $15,000 to $19,999 $20,000 to $24,999 $25,000 to $29,999  \
# 20                280                373                457
# 21                347                538                571
# 22              1,028              1,205              1,277
# 23                400                636                609
#
# 18 $30,000 to $34,999 $35,000 to $39,999 $40,000 to $44,999  ...  \
# 20                497                479                494  ...
# 21                613                629                601  ...
# 22              1,404              1,397              1,245  ...
# ...

# %%
df_FIN2018 = df_FIN2018.replace(',','', regex=True)
df_FIN2018.head()
# Out:
# 18 Characteristic Under $5,000 $5,000 to  $9,999 $10,000 to $14,999  \
# 20      Northeast          291               201                255
# 21        Midwest          233               205                392
# 22          South         1017               531                809
# 23           West          399               276                360
#
# 18 $15,000 to $19,999 $20,000 to $24,999 $25,000 to $29,999  \
# 20                280                373                457
# 21                347                538                571
# 22               1028               1205               1277
# 23                400                636                609
#
# 18 $30,000 to $34,999 $35,000 to $39,999 $40,000 to $44,999  ...  \
# 20                497                479                494  ...
# 21                613                629                601  ...
# 22               1404               1397               1245  ...
# ...

# %%
df_FIN2018[['Under $5,000','$5,000 to  $9,999','$10,000 to $14,999','$15,000 to $19,999','$20,000 to $24,999']] = df_FIN2018[['Under $5,000','$5,000 to  $9,999','$10,000 to $14,999','$15,000 to $19,999','$20,000 to $24,999']].apply(pd.to_numeric)
df_FIN2018[['$25,000 to $29,999','$30,000 to $34,999','$35,000 to $39,999','$40,000 to $44,999']] = df_FIN2018[['$25,000 to $29,999','$30,000 to $34,999','$35,000 to $39,999','$40,000 to $44,999']].apply(pd.to_numeric)
df_FIN2018[['$45,000 to $49,999','$50,000 to $54,999','$55,000 to $59,999','$60,000 to $64,999','$65,000 to $69,999','$70,000 to $74,999','$75,000 to $79,999','$80,000 to $84,999','$85,000 to $89,999','$90,000 to $94,999','$95,000 to $99,999']] = df_FIN2018[['$45,000 to $49,999','$50,000 to $54,999','$55,000 to $59,999','$60,000 to $64,999','$65,000 to $69,999','$70,000 to $74,999','$75,000 to $79,999','$80,000 to $84,999','$85,000 to $89,999','$90,000 to $94,999','$95,000 to $99,999']].apply(pd.to_numeric)
df_FIN2018[['$100,000 to $104,999','$105,000 to $109,999','$110,000 to $114,999','$115,000 to $119,999','$120,000 to $124,999','$125,000 to $129,999','$130,000 to $134,999','$135,000 to $139,999','$140,000 to $144,999','$145,000 to $149,999']] = df_FIN2018[['$100,000 to $104,999','$105,000 to $109,999','$110,000 to $114,999','$115,000 to $119,999','$120,000 to $124,999','$125,000 to $129,999','$130,000 to $134,999','$135,000 to $139,999','$140,000 to $144,999','$145,000 to $149,999']].apply(pd.to_numeric)
df_FIN2018[['$150,000 to $154,999','$155,000 to $159,999','$160,000 to $164,999','$165,000 to $169,999','$170,000 to $174,999','$175,000 to $179,999','$180,000 to $184,999','$185,000 to $189,999','$190,000 to $194,999','$195,000 to $199,999','$200,000 and over']] = df_FIN2018[['$150,000 to $154,999','$155,000 to $159,999','$160,000 to $164,999','$165,000 to $169,999','$170,000 to $174,999','$175,000 to $179,999','$180,000 to $184,999','$185,000 to $189,999','$190,000 to $194,999','$195,000 to $199,999','$200,000 and over']].apply(pd.to_numeric)
df_FIN2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4 entries, 20 to 23
# Data columns (total 42 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   (Characteristic,)        4 non-null      object
#  1   (Under $5,000,)          4 non-null      int64
#  2   ($5,000 to  $9,999,)     4 non-null      int64
#  3   ($10,000 to $14,999,)    4 non-null      int64
#  4   ($15,000 to $19,999,)    4 non-null      int64
#  5   ($20,000 to $24,999,)    4 non-null      int64
#  6   ($25,000 to $29,999,)    4 non-null      int64
#  7   ($30,000 to $34,999,)    4 non-null      int64
#  8   ($35,000 to $39,999,)    4 non-null      int64
#  9   ($40,000 to $44,999,)    4 non-null      int64
#  10  ($45,000 to $49,999,)    4 non-null      int64
#  11  ($50,000 to $54,999,)    4 non-null      int64
#  12  ($55,000 to $59,999,)    4 non-null      int64
#  13  ($60,000 to $64,999,)    4 non-null      int64
# ...

# %%
cl = ['Under $5,000','$5,000 to  $9,999','$10,000 to $14,999','$15,000 to $19,999','$20,000 to $24,999']
cl2 = ['$25,000 to $29,999','$30,000 to $34,999','$35,000 to $39,999','$40,000 to $44,999']
cl3 = ['$45,000 to $49,999','$50,000 to $54,999','$55,000 to $59,999','$60,000 to $64,999','$65,000 to $69,999','$70,000 to $74,999','$75,000 to $79,999','$80,000 to $84,999','$85,000 to $89,999','$90,000 to $94,999','$95,000 to $99,999']
cl4 = ['$100,000 to $104,999','$105,000 to $109,999','$110,000 to $114,999','$115,000 to $119,999','$120,000 to $124,999','$125,000 to $129,999','$130,000 to $134,999','$135,000 to $139,999','$140,000 to $144,999','$145,000 to $149,999']
cl5 = ['$150,000 to $154,999','$155,000 to $159,999','$160,000 to $164,999','$165,000 to $169,999','$170,000 to $174,999','$175,000 to $179,999','$180,000 to $184,999','$185,000 to $189,999','$190,000 to $194,999','$195,000 to $199,999','$200,000 and over']
df_FIN2018['$0 - $24,999'] = df_FIN2018[cl].sum(axis=1)
df_FIN2018['$25,000 - $49,999'] = df_FIN2018[cl2].sum(axis=1)
df_FIN2018['$50,000 - $99,999'] = df_FIN2018[cl3].sum(axis=1)
df_FIN2018['$100,000 - $149,999'] = df_FIN2018[cl4].sum(axis=1)
df_FIN2018['$150,000+'] = df_FIN2018[cl5].sum(axis=1)
df_FIN2018.head()
# Out:
# 18 Characteristic Under $5,000 $5,000 to  $9,999 $10,000 to $14,999  \
# 20      Northeast          291               201                255
# 21        Midwest          233               205                392
# 22          South         1017               531                809
# 23           West          399               276                360
#
# 18 $15,000 to $19,999 $20,000 to $24,999 $25,000 to $29,999  \
# 20                280                373                457
# 21                347                538                571
# 22               1028               1205               1277
# 23                400                636                609
#
# 18 $30,000 to $34,999 $35,000 to $39,999 $40,000 to $44,999  ...  \
# 20                497                479                494  ...
# 21                613                629                601  ...
# 22               1404               1397               1245  ...
# ...

# %%
df_FIN2018.loc[2018] = df_FIN2018.sum()
df_FIN2018["Year"] = '2018'
df_FIN2018.head()
# Out:
# 18               Characteristic Under $5,000 $5,000 to  $9,999  \
# 20                    Northeast          291               201
# 21                      Midwest          233               205
# 22                        South         1017               531
# 23                         West          399               276
# 2018  NortheastMidwestSouthWest         1940              1213
#
# 18   $10,000 to $14,999 $15,000 to $19,999 $20,000 to $24,999  \
# 20                  255                280                373
# 21                  392                347                538
# 22                  809               1028               1205
# 23                  360                400                636
# 2018               1816               2055               2752
#
# 18   $25,000 to $29,999 $30,000 to $34,999 $35,000 to $39,999  \
# 20                  457                497                479
# 21                  571                613                629
# ...

# %%
df_FIN2018_clean = df_FIN2018[['Year','$0 - $24,999','$25,000 - $49,999','$50,000 - $99,999','$100,000 - $149,999','$150,000+']]
df_FIN2018_clean.head()
# Out:
# 18    Year $0 - $24,999 $25,000 - $49,999 $50,000 - $99,999  \
# 20    2018         1400              1927              4432
# 21    2018         1715              2414              6434
# 22    2018         4590              5323             11561
# 23    2018         2071              2827              6694
# 2018  2018         9776             12491             29121
#
# 18   $100,000 - $149,999 $150,000+
# 20                  2597      3681
# 21                  3525      3465
# 22                  5560      5481
# 23                  3545      4263
# 2018               15227     16890

# %% [markdown]
# ##**2019**

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-8e29b849-43cd-4711-9e26-0ce70b99ce54" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8e29b849-43cd-4711-9e26-0ce70b99ce54">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving finc01_2019.csv to finc01_2019.csv

# %%
FIN2019 = open("finc01_2019.csv","r")

df_FIN2019 = pd.read_csv(FIN2019)
df_FIN2019 = df_FIN2019.drop(columns = ['Unnamed: 50','Unnamed: 49','Unnamed: 48','Unnamed: 47','Unnamed: 46','Unnamed: 45','Unnamed: 44','Unnamed: 43','Unnamed: 1'])
df_FIN2019.head()
# Out:
#   Table with row headers in column A and column headers in rows 8 through 9, 12 through 13, 19 through 20, 26 through 27, 34 through 35, 47 through 48, 63 through 64, 73 through 74, 83 through 84, and 97 through 98  \
# 0  FINC-01. Selected Characteristics of Families ...
# 1  For information on confidentiality protection,...
# 2  Source: U.S. Census Bureau, Current Population...
# 3  (Numbers in thousands. Families as of March of...
# 4  The Gini index is calculated using micro-sorte...
#
#   Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN        NaN        NaN
# 3        NaN        NaN        NaN        NaN        NaN        NaN
# 4        NaN        NaN        NaN        NaN        NaN        NaN
#
# ...

# %%
df_FIN2019.columns = [df_FIN2019.iloc[17]]

df_FIN2019 = df_FIN2019.drop(labels=18,axis=0)
df_FIN2019 = df_FIN2019.iloc[18:22]
df_FIN2019.head()
# Out:
# 17 Characteristic Under $5,000 $5,000 to $9,999 $10,000 to $14,999  \
# 19      Northeast          244              164                201
# 20        Midwest          270              235                231
# 21          South          824              481                681
# 22           West          361              220                288
#
# 17 $15,000 to $19,999 $20,000 to $24,999 $25,000 to $29,999  \
# 19                280                370                429
# 20                332                411                545
# 21                788                976              1,163
# 22                410                456                584
#
# 17 $30,000 to $34,999 $35,000 to $39,999 $40,000 to $44,999  ...  \
# 19                407                405                460  ...
# 20                593                549                664  ...
# 21              1,283              1,199              1,326  ...
# ...

# %%
df_FIN2019 = df_FIN2019.replace(',','', regex=True)
df_FIN2019.head()
# Out:
# 17 Characteristic Under $5,000 $5,000 to $9,999 $10,000 to $14,999  \
# 19      Northeast          244              164                201
# 20        Midwest          270              235                231
# 21          South          824              481                681
# 22           West          361              220                288
#
# 17 $15,000 to $19,999 $20,000 to $24,999 $25,000 to $29,999  \
# 19                280                370                429
# 20                332                411                545
# 21                788                976               1163
# 22                410                456                584
#
# 17 $30,000 to $34,999 $35,000 to $39,999 $40,000 to $44,999  ...  \
# 19                407                405                460  ...
# 20                593                549                664  ...
# 21               1283               1199               1326  ...
# ...

# %%
df_FIN2019[['Under $5,000','$5,000 to $9,999','$10,000 to $14,999','$15,000 to $19,999','$20,000 to $24,999']] = df_FIN2019[['Under $5,000','$5,000 to $9,999','$10,000 to $14,999','$15,000 to $19,999','$20,000 to $24,999']].apply(pd.to_numeric)
df_FIN2019[['$25,000 to $29,999','$30,000 to $34,999','$35,000 to $39,999','$40,000 to $44,999']] = df_FIN2019[['$25,000 to $29,999','$30,000 to $34,999','$35,000 to $39,999','$40,000 to $44,999']].apply(pd.to_numeric)
df_FIN2019[['$45,000 to $49,999','$50,000 to $54,999','$55,000 to $59,999','$60,000 to $64,999','$65,000 to $69,999','$70,000 to $74,999','$75,000 to $79,999','$80,000 to $84,999','$85,000 to $89,999','$90,000 to $94,999','$95,000 to $99,999']] = df_FIN2019[['$45,000 to $49,999','$50,000 to $54,999','$55,000 to $59,999','$60,000 to $64,999','$65,000 to $69,999','$70,000 to $74,999','$75,000 to $79,999','$80,000 to $84,999','$85,000 to $89,999','$90,000 to $94,999','$95,000 to $99,999']].apply(pd.to_numeric)
df_FIN2019[['$100,000 to $104,999','$105,000 to $109,999','$110,000 to $114,999','$115,000 to $119,999','$120,000 to $124,999','$125,000 to $129,999','$130,000 to $134,999','$135,000 to $139,999','$140,000 to $144,999','$145,000 to $149,999']] = df_FIN2019[['$100,000 to $104,999','$105,000 to $109,999','$110,000 to $114,999','$115,000 to $119,999','$120,000 to $124,999','$125,000 to $129,999','$130,000 to $134,999','$135,000 to $139,999','$140,000 to $144,999','$145,000 to $149,999']].apply(pd.to_numeric)
df_FIN2019[['$150,000 to $154,999','$155,000 to $159,999','$160,000 to $164,999','$165,000 to $169,999','$170,000 to $174,999','$175,000 to $179,999','$180,000 to $184,999','$185,000 to $189,999','$190,000 to $194,999','$195,000 to $199,999','$200,000 and over']] = df_FIN2019[['$150,000 to $154,999','$155,000 to $159,999','$160,000 to $164,999','$165,000 to $169,999','$170,000 to $174,999','$175,000 to $179,999','$180,000 to $184,999','$185,000 to $189,999','$190,000 to $194,999','$195,000 to $199,999','$200,000 and over']].apply(pd.to_numeric)
df_FIN2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4 entries, 19 to 22
# Data columns (total 42 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   (Characteristic,)        4 non-null      object
#  1   (Under $5,000,)          4 non-null      int64
#  2   ($5,000 to $9,999,)      4 non-null      int64
#  3   ($10,000 to $14,999,)    4 non-null      int64
#  4   ($15,000 to $19,999,)    4 non-null      int64
#  5   ($20,000 to $24,999,)    4 non-null      int64
#  6   ($25,000 to $29,999,)    4 non-null      int64
#  7   ($30,000 to $34,999,)    4 non-null      int64
#  8   ($35,000 to $39,999,)    4 non-null      int64
#  9   ($40,000 to $44,999,)    4 non-null      int64
#  10  ($45,000 to $49,999,)    4 non-null      int64
#  11  ($50,000 to $54,999,)    4 non-null      int64
#  12  ($55,000 to $59,999,)    4 non-null      int64
#  13  ($60,000 to $64,999,)    4 non-null      int64
# ...

# %%
cl = ['Under $5,000','$5,000 to $9,999','$10,000 to $14,999','$15,000 to $19,999','$20,000 to $24,999']
cl2 = ['$25,000 to $29,999','$30,000 to $34,999','$35,000 to $39,999','$40,000 to $44,999']
cl3 = ['$45,000 to $49,999','$50,000 to $54,999','$55,000 to $59,999','$60,000 to $64,999','$65,000 to $69,999','$70,000 to $74,999','$75,000 to $79,999','$80,000 to $84,999','$85,000 to $89,999','$90,000 to $94,999','$95,000 to $99,999']
cl4 = ['$100,000 to $104,999','$105,000 to $109,999','$110,000 to $114,999','$115,000 to $119,999','$120,000 to $124,999','$125,000 to $129,999','$130,000 to $134,999','$135,000 to $139,999','$140,000 to $144,999','$145,000 to $149,999']
cl5 = ['$150,000 to $154,999','$155,000 to $159,999','$160,000 to $164,999','$165,000 to $169,999','$170,000 to $174,999','$175,000 to $179,999','$180,000 to $184,999','$185,000 to $189,999','$190,000 to $194,999','$195,000 to $199,999','$200,000 and over']
df_FIN2019['$0 - $24,999'] = df_FIN2019[cl].sum(axis=1)
df_FIN2019['$25,000 - $49,999'] = df_FIN2019[cl2].sum(axis=1)
df_FIN2019['$50,000 - $99,999'] = df_FIN2019[cl3].sum(axis=1)
df_FIN2019['$100,000 - $149,999'] = df_FIN2019[cl4].sum(axis=1)
df_FIN2019['$150,000+'] = df_FIN2019[cl5].sum(axis=1)
df_FIN2019.head()
# Out:
# 17 Characteristic Under $5,000 $5,000 to $9,999 $10,000 to $14,999  \
# 19      Northeast          244              164                201
# 20        Midwest          270              235                231
# 21          South          824              481                681
# 22           West          361              220                288
#
# 17 $15,000 to $19,999 $20,000 to $24,999 $25,000 to $29,999  \
# 19                280                370                429
# 20                332                411                545
# 21                788                976               1163
# 22                410                456                584
#
# 17 $30,000 to $34,999 $35,000 to $39,999 $40,000 to $44,999  ...  \
# 19                407                405                460  ...
# 20                593                549                664  ...
# 21               1283               1199               1326  ...
# ...

# %%
df_FIN2019.loc[2019] = df_FIN2019.sum()
df_FIN2019["Year"] = '2019'
df_FIN2019.head()
# Out:
# 17               Characteristic Under $5,000 $5,000 to $9,999  \
# 19                    Northeast          244              164
# 20                      Midwest          270              235
# 21                        South          824              481
# 22                         West          361              220
# 2019  NortheastMidwestSouthWest         1699             1100
#
# 17   $10,000 to $14,999 $15,000 to $19,999 $20,000 to $24,999  \
# 19                  201                280                370
# 20                  231                332                411
# 21                  681                788                976
# 22                  288                410                456
# 2019               1401               1810               2213
#
# 17   $25,000 to $29,999 $30,000 to $34,999 $35,000 to $39,999  \
# 19                  429                407                405
# 20                  545                593                549
# ...

# %%
df_FIN2019_clean = df_FIN2019[['Year','$0 - $24,999','$25,000 - $49,999','$50,000 - $99,999','$100,000 - $149,999','$150,000+']]
df_FIN2019_clean.head()
# Out:
# 17    Year $0 - $24,999 $25,000 - $49,999 $50,000 - $99,999  \
# 19    2019         1259              1701              4162
# 20    2019         1479              2351              6102
# 21    2019         3750              4971             11255
# 22    2019         1735              2545              6490
# 2019  2019         8223             11568             28009
#
# 17   $100,000 - $149,999 $150,000+
# 19                  2656      4236
# 20                  3630      4067
# 21                  5686      6788
# 22                  3757      5084
# 2019               15729     20175

# %% [markdown]
# ##**2020**

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-1674197e-18cc-4ec7-9730-790cbe3fc254" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1674197e-18cc-4ec7-9730-790cbe3fc254">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving finc01_2020.csv to finc01_2020.csv

# %%
FIN2020 = open("finc01_2020.csv","r")

df_FIN2020 = pd.read_csv(FIN2020)
df_FIN2020 = df_FIN2020.drop(columns = ['Unnamed: 50','Unnamed: 49','Unnamed: 48','Unnamed: 47','Unnamed: 46','Unnamed: 45','Unnamed: 44','Unnamed: 43','Unnamed: 1'])
df_FIN2020.head()
# Out:
#   Table with row headers in column A and column headers in rows 8 through 9, 12 through 13, 19 through 20, 26 through 27, 34 through 35, 47 through 48, 63 through 64, 73 through 74, 83 through 84, and 97 through 98  \
# 0  FINC-01. Selected Characteristics of Families ...
# 1  Information on confidentiality protection, sam...
# 2  Source: U.S. Census Bureau, Current Population...
# 3  (Numbers in thousands. Families as of March of...
# 4  The Gini index is calculated using micro-sorte...
#
#   Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN        NaN        NaN
# 3        NaN        NaN        NaN        NaN        NaN        NaN
# 4        NaN        NaN        NaN        NaN        NaN        NaN
#
# ...

# %%
df_FIN2020.columns = [df_FIN2020.iloc[17]]

df_FIN2020 = df_FIN2020.drop(labels=18,axis=0)
df_FIN2020 = df_FIN2020.iloc[18:22]
df_FIN2020.head()
# Out:
# 17 Characteristic Under $5,000 $5,000 to $9,999 $10,000 to $14,999  \
# 19      Northeast          285              200                229
# 20        Midwest          318              255                256
# 21          South        1,037              481                706
# 22           West          431              218                364
#
# 17 $15,000 to $19,999 $20,000 to $24,999 $25,000 to $29,999  \
# 19                311                327                403
# 20                358                464                515
# 21                939              1,213              1,157
# 22                393                489                575
#
# 17 $30,000 to $34,999 $35,000 to $39,999 $40,000 to $44,999  ...  \
# 19                411                434                433  ...
# 20                555                578                670  ...
# 21              1,324              1,158              1,312  ...
# ...

# %%
df_FIN2020 = df_FIN2020.replace(',','', regex=True)
df_FIN2020.head()
# Out:
# 17 Characteristic Under $5,000 $5,000 to $9,999 $10,000 to $14,999  \
# 19      Northeast          285              200                229
# 20        Midwest          318              255                256
# 21          South         1037              481                706
# 22           West          431              218                364
#
# 17 $15,000 to $19,999 $20,000 to $24,999 $25,000 to $29,999  \
# 19                311                327                403
# 20                358                464                515
# 21                939               1213               1157
# 22                393                489                575
#
# 17 $30,000 to $34,999 $35,000 to $39,999 $40,000 to $44,999  ...  \
# 19                411                434                433  ...
# 20                555                578                670  ...
# 21               1324               1158               1312  ...
# ...

# %%
df_FIN2020[['Under $5,000','$5,000 to $9,999','$10,000 to $14,999','$15,000 to $19,999','$20,000 to $24,999']] = df_FIN2020[['Under $5,000','$5,000 to $9,999','$10,000 to $14,999','$15,000 to $19,999','$20,000 to $24,999']].apply(pd.to_numeric)
df_FIN2020[['$25,000 to $29,999','$30,000 to $34,999','$35,000 to $39,999','$40,000 to $44,999']] = df_FIN2020[['$25,000 to $29,999','$30,000 to $34,999','$35,000 to $39,999','$40,000 to $44,999']].apply(pd.to_numeric)
df_FIN2020[['$45,000 to $49,999','$50,000 to $54,999','$55,000 to $59,999','$60,000 to $64,999','$65,000 to $69,999','$70,000 to $74,999','$75,000 to $79,999','$80,000 to $84,999','$85,000 to $89,999','$90,000 to $94,999','$95,000 to $99,999']] = df_FIN2020[['$45,000 to $49,999','$50,000 to $54,999','$55,000 to $59,999','$60,000 to $64,999','$65,000 to $69,999','$70,000 to $74,999','$75,000 to $79,999','$80,000 to $84,999','$85,000 to $89,999','$90,000 to $94,999','$95,000 to $99,999']].apply(pd.to_numeric)
df_FIN2020[['$100,000 to $104,999','$105,000 to $109,999','$110,000 to $114,999','$115,000 to $119,999','$120,000 to $124,999','$125,000 to $129,999','$130,000 to $134,999','$135,000 to $139,999','$140,000 to $144,999','$145,000 to $149,999']] = df_FIN2020[['$100,000 to $104,999','$105,000 to $109,999','$110,000 to $114,999','$115,000 to $119,999','$120,000 to $124,999','$125,000 to $129,999','$130,000 to $134,999','$135,000 to $139,999','$140,000 to $144,999','$145,000 to $149,999']].apply(pd.to_numeric)
df_FIN2020[['$150,000 to $154,999','$155,000 to $159,999','$160,000 to $164,999','$165,000 to $169,999','$170,000 to $174,999','$175,000 to $179,999','$180,000 to $184,999','$185,000 to $189,999','$190,000 to $194,999','$195,000 to $199,999','$200,000 and over']] = df_FIN2020[['$150,000 to $154,999','$155,000 to $159,999','$160,000 to $164,999','$165,000 to $169,999','$170,000 to $174,999','$175,000 to $179,999','$180,000 to $184,999','$185,000 to $189,999','$190,000 to $194,999','$195,000 to $199,999','$200,000 and over']].apply(pd.to_numeric)
df_FIN2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4 entries, 19 to 22
# Data columns (total 42 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   (Characteristic,)        4 non-null      object
#  1   (Under $5,000,)          4 non-null      int64
#  2   ($5,000 to $9,999,)      4 non-null      int64
#  3   ($10,000 to $14,999,)    4 non-null      int64
#  4   ($15,000 to $19,999,)    4 non-null      int64
#  5   ($20,000 to $24,999,)    4 non-null      int64
#  6   ($25,000 to $29,999,)    4 non-null      int64
#  7   ($30,000 to $34,999,)    4 non-null      int64
#  8   ($35,000 to $39,999,)    4 non-null      int64
#  9   ($40,000 to $44,999,)    4 non-null      int64
#  10  ($45,000 to $49,999,)    4 non-null      int64
#  11  ($50,000 to $54,999,)    4 non-null      int64
#  12  ($55,000 to $59,999,)    4 non-null      int64
#  13  ($60,000 to $64,999,)    4 non-null      int64
# ...

# %%
cl = ['Under $5,000','$5,000 to $9,999','$10,000 to $14,999','$15,000 to $19,999','$20,000 to $24,999']
cl2 = ['$25,000 to $29,999','$30,000 to $34,999','$35,000 to $39,999','$40,000 to $44,999']
cl3 = ['$45,000 to $49,999','$50,000 to $54,999','$55,000 to $59,999','$60,000 to $64,999','$65,000 to $69,999','$70,000 to $74,999','$75,000 to $79,999','$80,000 to $84,999','$85,000 to $89,999','$90,000 to $94,999','$95,000 to $99,999']
cl4 = ['$100,000 to $104,999','$105,000 to $109,999','$110,000 to $114,999','$115,000 to $119,999','$120,000 to $124,999','$125,000 to $129,999','$130,000 to $134,999','$135,000 to $139,999','$140,000 to $144,999','$145,000 to $149,999']
cl5 = ['$150,000 to $154,999','$155,000 to $159,999','$160,000 to $164,999','$165,000 to $169,999','$170,000 to $174,999','$175,000 to $179,999','$180,000 to $184,999','$185,000 to $189,999','$190,000 to $194,999','$195,000 to $199,999','$200,000 and over']
df_FIN2020['$0 - $24,999'] = df_FIN2020[cl].sum(axis=1)
df_FIN2020['$25,000 - $49,999'] = df_FIN2020[cl2].sum(axis=1)
df_FIN2020['$50,000 - $99,999'] = df_FIN2020[cl3].sum(axis=1)
df_FIN2020['$100,000 - $149,999'] = df_FIN2020[cl4].sum(axis=1)
df_FIN2020['$150,000+'] = df_FIN2019[cl5].sum(axis=1)
df_FIN2020.head()
# Out:
# 17 Characteristic Under $5,000 $5,000 to $9,999 $10,000 to $14,999  \
# 19      Northeast          285              200                229
# 20        Midwest          318              255                256
# 21          South         1037              481                706
# 22           West          431              218                364
#
# 17 $15,000 to $19,999 $20,000 to $24,999 $25,000 to $29,999  \
# 19                311                327                403
# 20                358                464                515
# 21                939               1213               1157
# 22                393                489                575
#
# 17 $30,000 to $34,999 $35,000 to $39,999 $40,000 to $44,999  ...  \
# 19                411                434                433  ...
# 20                555                578                670  ...
# 21               1324               1158               1312  ...
# ...

# %%
df_FIN2020.loc[2020] = df_FIN2020.sum()
df_FIN2020["Year"] = '2020'
df_FIN2020.head()
# Out:
# 17               Characteristic Under $5,000 $5,000 to $9,999  \
# 19                    Northeast          285              200
# 20                      Midwest          318              255
# 21                        South         1037              481
# 22                         West          431              218
# 2020  NortheastMidwestSouthWest         2071             1154
#
# 17   $10,000 to $14,999 $15,000 to $19,999 $20,000 to $24,999  \
# 19                  229                311                327
# 20                  256                358                464
# 21                  706                939               1213
# 22                  364                393                489
# 2020               1555               2001               2493
#
# 17   $25,000 to $29,999 $30,000 to $34,999 $35,000 to $39,999  \
# 19                  403                411                434
# 20                  515                555                578
# ...

# %%
df_FIN2020_clean = df_FIN2020[['Year','$0 - $24,999','$25,000 - $49,999','$50,000 - $99,999','$100,000 - $149,999','$150,000+']]
df_FIN2020_clean.head()
# Out:
# 17    Year $0 - $24,999 $25,000 - $49,999 $50,000 - $99,999  \
# 19    2020         1352              1681              4152
# 20    2020         1651              2318              6150
# 21    2020         4376              4951             11069
# 22    2020         1895              2536              6435
# 2020  2020         9274             11486             27806
#
# 17   $100,000 - $149,999 $150,000+
# 19                  2723      4236
# 20                  3300      4067
# 21                  5750      6788
# 22                  3703      5084
# 2020               15476     20175

# %% [markdown]
# ##**CONCAT**

# %%
frames = [df_FIN2020_clean, df_FIN2019_clean, df_FIN2018_clean]
df_all = pd.concat(frames)
df_all.head(15)
# Out:
#       Year $0 - $24,999 $25,000 - $49,999 $50,000 - $99,999  \
# 19    2020         1352              1681              4152
# 20    2020         1651              2318              6150
# 21    2020         4376              4951             11069
# 22    2020         1895              2536              6435
# 2020  2020         9274             11486             27806
# 19    2019         1259              1701              4162
# 20    2019         1479              2351              6102
# 21    2019         3750              4971             11255
# 22    2019         1735              2545              6490
# 2019  2019         8223             11568             28009
# 20    2018         1400              1927              4432
# 21    2018         1715              2414              6434
# 22    2018         4590              5323             11561
# 23    2018         2071              2827              6694
# 2018  2018         9776             12491             29121
#
# ...

# %%
df_all_clean = df_all.iloc[[4,9,14]]
df_all_clean.columns = ['Year','$0 - $24,999','$25,000 - $49,999','$50,000 - $99,999','$100,000 - $149,999','$150,000+']
df_all_clean = df_all_clean[['$0 - $24,999','$25,000 - $49,999','$50,000 - $99,999','$100,000 - $149,999','$150,000+']]
df_all_clean.head()
# Out:
#       $0 - $24,999  $25,000 - $49,999  $50,000 - $99,999  $100,000 - $149,999  \
# 2020          9274              11486              27806                15476
# 2019          8223              11568              28009                15729
# 2018          9776              12491              29121                15227
#
#       $150,000+
# 2020      20175
# 2019      20175
# 2018      16890

# %%
df_all_final = df_all_clean.T
df_all_final.reset_index(inplace=True)
df_all_final.columns = ['Salary Range','2020','2019','2018']
df_all_final
# Out:
#           Salary Range   2020   2019   2018
# 0         $0 - $24,999   9274   8223   9776
# 1    $25,000 - $49,999  11486  11568  12491
# 2    $50,000 - $99,999  27806  28009  29121
# 3  $100,000 - $149,999  15476  15729  15227
# 4            $150,000+  20175  20175  16890

# %% [markdown]
# ##**PLOTS**

# %%
ax = df_all_final.plot(x='Salary Range',y=['2020','2019','2018'],kind="line",title='Population (In the Thousands) In Each Salary Range (2018-2020)',figsize=(10, 10))
ax.set_ylabel('Population (In the Thousands)')
plt.savefig(f"{images_dir}/plotsKF.png")
plt.show()

# %%
plt.figure(figsize = (25,8))
plt.hist(df_all_final['Salary Range'], weights = df_all_final['2020'], color = 'blue')
plt.grid(axis = 'y')
plt.xlabel('Salary Range')
plt.ylabel('Population (In the Thousands)')
plt.title('Population (In the Thousands) In Each Salary Range (2020)')
plt.savefig(f"{images_dir}/HG1KF.png")
plt.show()

# %%
plt.figure(figsize = (25,8))
plt.hist(df_all_final['Salary Range'], weights = df_all_final['2019'], color = 'orange')
plt.grid(axis = 'y')
plt.xlabel('Salary Range')
plt.ylabel('Population (In the Thousands)')
plt.title('Population (In the Thousands) In Each Salary Range (2019)')
plt.savefig(f"{images_dir}/HG2KF.png")
plt.show()

# %%
plt.figure(figsize = (25,8))
plt.hist(df_all_final['Salary Range'], weights = df_all_final['2018'], color = 'green')
plt.grid(axis = 'y')
plt.xlabel('Salary Range')
plt.ylabel('Population (In the Thousands)')
plt.title('Population (In the Thousands) In Each Salary Range (2018)')
plt.savefig(f"{images_dir}/HG3KF.png")
plt.show()

# %%
plt.figure(figsize = (25,8))
plt.hist(df_all_final['Salary Range'], weights = df_all_final['2018'], color = 'green')
plt.hist(df_all_final['Salary Range'], weights = df_all_final['2019'], color = 'orange')
plt.hist(df_all_final['Salary Range'], weights = df_all_final['2020'], color = 'blue')
plt.grid(axis = 'y')
plt.legend(['2018','2019','2020'])
plt.xlabel('Salary Range')
plt.ylabel('Population (In the Thousands)')
plt.title('Population (In the Thousands) In Each Salary Range (2018-2020)')
plt.savefig(f"{images_dir}/HG4KF.png")
plt.show()
